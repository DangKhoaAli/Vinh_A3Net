# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git config --global user.email "khoanguyen12062005@gmail.com"
# !git config --global user.name "DangKhoaAli"

# %%
from kaggle_secrets import UserSecretsClient
import os

user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GH_TOKEN")

# Thông tin repo của ông
username = "DangKhoaAli"
repo_name = "Vinh_A3Net"

# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
repo_url = f"https://{username}:{token}@github.com/{username}/{repo_name}.git"

# %cd /kaggle/working/

if not os.path.exists(repo_name):
    print("--- Đang clone repo mới ---")
    # !git clone {repo_url}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {repo_name}
    # !git pull
    # %cd ..

# %%
# %cd /kaggle/working/RRG
# !ls -R

# %%
# !cat /kaggle/working/Vinh_A3Net/run_iu_xray.sh

# %%
# !cat /kaggle/working/Vinh_A3Net/test_iu_xray.sh

# %%
# !ls /kaggle/input/

# %%
# !ls /kaggle/input/datasets

# %%
# !ls /kaggle/input/datasets/nadkli

# %%
# !ls /kaggle/input/datasets/nadkli/dataset

# %%
# !ls /kaggle/input/datasets/nadkli/dataset/data/iu_xray
# !ls /kaggle/input/datasets/nadkli/dataset/data/iu_xray/images | head

# %%
# !pwd
# !ls -lah
# !find /kaggle/working -maxdepth 3 -name "main.py"

# %%
# %cd /kaggle/working/Vinh_A3Net
# !ls

# %%
# !python /kaggle/working/Vinh_A3Net/main.py \
  --image_dir /kaggle/input/datasets/nadkli/dataset/data/iu_xray/images/ \
  --ann_path /kaggle/input/datasets/nadkli/dataset/data/iu_xray/annotation.json \
  --dataset_name iu_xray \
  --max_seq_length 60 \
  --threshold 3 \
  --epochs 100 \
  --batch_size 16 \
  --lr_ve 5e-5 \
  --lr_ed 3e-4 \
  --step_size 5 \
  --gamma 0.8 \
  --num_layers 4 \
  --topk 32 \
  --cmm_size 2048 \
  --cmm_dim 512 \
  --seed 7580 \
  --beam_size 3 \
  --save_dir /kaggle/working/results/iu_xray_seed_02032026_ver2/ \
  --log_period 50

# %%
# !python /kaggle/working/Vinh_A3Net/test.py \
 --image_dir /kaggle/input/datasets/nadkli/dataset/data/iu_xray/images/ \
 --ann_path /kaggle/input/datasets/nadkli/dataset/data/iu_xray/annotation.json \
 --dataset_name iu_xray \
 --max_seq_length 60 \
 --threshold 3 \
 --batch_size 16 \
 --epochs 100 \
 --save_dir results/iu_xray \
 --step_size 5\
 --gamma 0.8 \
 --log_period 50 \
 --seed 7580 \
 --lr_ve 5e-5 \
 --lr_ed 3e-4 \
 --cmm_size 2048 \
 --cmm_dim 512 \
 --beam_size 3 \
 --topk 32 \
 --num_layers 4 \
 --load /kaggle/input/models/nadkli/xray-caption-model/pytorch/default/1/model_best.pth

# %%
# !python /kaggle/working/Vinh_A3Net/test.py \
 --image_dir /kaggle/input/datasets/nadkli/dataset/data/iu_xray/images/ \
 --ann_path /kaggle/input/datasets/nadkli/dataset/data/iu_xray/annotation.json \
 --dataset_name iu_xray \
 --max_seq_length 60 \
 --threshold 3 \
 --batch_size 16 \
 --epochs 100 \
 --save_dir results/iu_xray \
 --step_size 5\
 --gamma 0.8 \
 --log_period 50 \
 --seed 7580 \
 --lr_ve 5e-5 \
 --lr_ed 3e-4 \
 --cmm_size 2048 \
 --cmm_dim 512 \
 --beam_size 3 \
 --topk 32 \
 --num_layers 4 \
 --load /kaggle/input/models/nadkli/xray-caption-model/pytorch/default/1/model_best.pth \
 --image_path1 /kaggle/input/datasets/nadkli/dataset/data/iu_xray/images/CXR1902_IM-0586/0.png \
 --image_path2 /kaggle/input/datasets/nadkli/dataset/data/iu_xray/images/CXR1902_IM-0586/1.png
